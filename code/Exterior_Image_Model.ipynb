# %% [markdown]
# ## **Setting Things Up**
#
# **1 If you haven't already, please hit :**
#
# `File > Save a Copy in Drive`
#
# **to copy this notebook to your Google drive, and work on a copy. If you don't do this, your changes won't be saved!**
#
#
# **2 In order to use a GPU with your notebook, select :**
#
# `Runtime > Change runtime type`
#
# **menu, and then set the hardware accelerator dropdown to GPU. This can significantly speed up the training process.**
#
# **3 In order to have enough memory with your notebook, select :**
#
# `Runtime > Change runtime type`
#
# **menu, and then select High-RAM in the Runtime shape dropdown.**
#
# To facilitate your initial progress, we have included a ready-to-use code on Google Colab for this problem. It allows you to get started immediately without the need to install any software libraries. Additionally, if you prefer not to use Google Colab and prefer setting up your own programming environment or employing alternative methods, the provided files and code will still be valuable.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Jun 21 07:35:50 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    43W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# -*-coding:utf8 -*-
import tensorflow as tf
# print("TensorFlow version:", tf.__version__)

import os

import pandas as pd
import numpy as np

from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
from PIL import Image

from tensorflow.python import keras
from keras.layers import Dense, Flatten, Conv2D
from keras.optimizers import RMSprop, Adam, SGD
from keras.callbacks import LearningRateScheduler
from keras.applications.vgg16 import VGG16
# from keras.applications.xception import Xception
# from keras.applications.resnet_v2 import ResNet152V2
# from keras.applications.inception_v3 import InceptionV3
# from keras.applications.inception_resnet_v2 import InceptionResNetV2
# from keras.applications.densenet import DenseNet201
# from keras.applications.efficientnet import EfficientNetB7
# from keras.applications.efficientnet_v2 import EfficientNetV2L
from keras import Model, Input, layers

# %%
from google.colab import drive
drive.mount('/content/drive')

# change to your personal project address

# %cd /content/drive/MyDrive/Colab Notebooks/Vehicle Rating Prediction/new_images_with_folder
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Vehicle Rating Prediction/new_images_with_folder

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Vehicle Rating Prediction/new_images_with_folder
# !unzip "new_images_with_folder.zip"
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#    creating: 2007 Nissan Sentra/
#   inflating: 2007 Nissan Sentra/2007 Nissan Sentra.jpg
#    creating: 2007 Nissan Versa/
#   inflating: 2007 Nissan Versa/2007 Nissan Versa.jpg
#    creating: 2007 Pontiac G6/
#   inflating: 2007 Pontiac G6/2007 Pontiac G6.jpg
#    creating: 2007 Pontiac Torrent/
#   inflating: 2007 Pontiac Torrent/2007 Pontiac Torrent.jpg
#    creating: 2007 Pontiac Vibe/
#   inflating: 2007 Pontiac Vibe/2007 Pontiac Vibe.jpg
#    creating: 2007 Saab 9-3 Wagon/
#   inflating: 2007 Saab 9-3 Wagon/2007 Saab 9-3 Wagon.jpg
#    creating: 2007 Saab 9-3/
#   inflating: 2007 Saab 9-3/2007 Saab 9-3.jpg
#    creating: 2007 Saturn Aura/
#   inflating: 2007 Saturn Aura/2007 Saturn Aura.jpg
#    creating: 2007 Saturn Ion/
#   inflating: 2007 Saturn Ion/2007 Saturn Ion.jpg
#    creating: 2007 Saturn Outlook/
#   inflating: 2007 Saturn Outlook/2007 Saturn Outlook.jpg
#    creating: 2007 Scion tC/
#   inflating: 2007 Scion tC/2007 Scion tC.jpg
#    creating: 2007 Subaru Forester/
#   inflating: 2007 Subaru Forester/2007 Subaru Forester.jpg
#    creating: 2007 Subaru Impreza Wagon/
#   inflating: 2022 Subaru Impreza/2022 Subaru Impreza.jpg
#    creating: 2022 Subaru Legacy/
#   inflating: 2022 Subaru Legacy/2022 Subaru Legacy.jpg
#    creating: 2022 Subaru Outback/
#   inflating: 2022 Subaru Outback/2022 Subaru Outback.jpg
#    creating: 2022 Toyota 4Runner/
#   inflating: 2022 Toyota 4Runner/2022 Toyota 4Runner.jpg
#    creating: 2022 Toyota Avalon/
#   inflating: 2022 Toyota Avalon/2022 Toyota Avalon.jpg
#    creating: 2022 Toyota C-HR/
#   inflating: 2022 Toyota C-HR/2022 Toyota C-HR.jpg
#    creating: 2022 Toyota Corolla Hybrid/
#   inflating: 2022 Toyota Corolla Hybrid/2022 Toyota Corolla Hybrid.jpg
#    creating: 2022 Toyota Corolla/
#   inflating: 2022 Toyota Corolla/2022 Toyota Corolla.jpg
#    creating: 2022 Toyota Highlander/
#   inflating: 2022 Toyota Highlander/2022 Toyota Highlander.jpg
#    creating: 2022 Toyota Prius Prime/
#   inflating: 2022 Toyota Prius Prime/2022 Toyota Prius Prime.jpg
#    creating: 2022 Toyota RAV4/
#   inflating: 2022 Toyota RAV4/2022 Toyota RAV4.jpg
#    creating: 2022 Toyota Sienna/
#   inflating: 2022 Toyota Sienna/2022 Toyota Sienna.jpg
#    creating: 2022 Toyota Tacoma/
#   inflating: 2022 Toyota Tacoma/2022 Toyota Tacoma.jpg
#    creating: 2022 Volkswagen Atlas/
#   inflating: 2022 Volkswagen Atlas/2022 Volkswagen Atlas.jpg
#    creating: 2022 Volkswagen Tiguan/
#   inflating: 2022 Volkswagen Tiguan/2022 Volkswagen Tiguan.jpg
#    creating: 2022 Volvo V60/
#   inflating: 2022 Volvo V60/2022 Volvo V60.jpg
#    creating: 2022 Volvo XC40/
#   inflating: 2022 Volvo XC40/2022 Volvo XC40.jpg
#    creating: 2022 Volvo XC90/
#   inflating: 2022 Volvo XC90/2022 Volvo XC90.jpg

# %%
# change to your personal project address

# %cd /content/drive/MyDrive/Colab Notebooks/Vehicle Rating Prediction
# Out:
# /content/drive/MyDrive/Colab Notebooks/Vehicle Rating Prediction

# %% [markdown]
# ## **1 Data Processing**

# %%
var = "total score"
# var = "safety score"
# var = "performance score"
# var = "critics score"
# var = "interior score"

# %%
# 1 first we need to get the total score information from the csv file
# read info_data
file_name = "parametric data 2571 normalize " + var + ".csv"
info_data = pd.read_csv(file_name)
# get numpy matrix which only contains data (do not contain the title)
info_data = np.array(info_data)
print(info_data.shape)  # (2579, 303)
print(len(info_data))
print(info_data.shape[1])
# Out:
# (2571, 310)
# 2571
# 310

# %%
# Input Parametric Data (2571x303)
# column 0: origin index
# column 1: model name
# column 2-303: parametric feature
# column 304: total score
# column 305: critics score
# column 306: performance score
# column 307: interior score
# column 308: safety score
# column 309: data split index => 1: train data; 2: validation data; 3:test data

# %%
# train data shuffle index
num1 = 2055
idx1 = tf.range(num1)
idx1 = tf.random.shuffle(idx1)
# print(idx1)
# print(idx1[0])
with tf.compat.v1.Session():
    index1 = idx1.numpy()
# print(index1.shape)
# print(index1[0])

# validation data shuffle index
num2 = 258
idx2 = tf.range(num2)
idx2 = tf.random.shuffle(idx2)
# print(idx2)
# print(idx2[0])
with tf.compat.v1.Session():
    index2 = idx2.numpy()
# print(index2.shape)
# print(index2[0])

# test data shuffle index
num3 = 258
idx3 = tf.range(num3)
idx3 = tf.random.shuffle(idx3)
# print(idx3)
# print(idx3[0])
with tf.compat.v1.Session():
    index3 = idx3.numpy()
# print(index3.shape)
# print(index3[0])

# %%
# assign the parametric data
# To predict the total score, you will need to assign the y variable using the values in column 304 of the parametric data.
# column 304: total score
# column 305: critics score
# column 306: performance score
# column 307: interior score
# column 308: safety score
y_train_tab = np.zeros((num1, 1))
for i in range(num1):
    y_train_tab[i] = np.array(info_data[index1[i], 304], dtype=float)
y_train_tab = tf.convert_to_tensor(y_train_tab)
y_train = y_train_tab
# print(y_train_tab)

y_validation_tab = np.zeros((num2, 1))
for i in range(num2):
    y_validation_tab[i] = np.array(info_data[index2[i] + num1, 304], dtype=float)
y_validation_tab = tf.convert_to_tensor(y_validation_tab)
y_validation = y_validation_tab
# print(y_validation_tab)

y_test_tab = np.zeros((num3, 1))
for i in range(num3):
    y_test_tab[i] = np.array(info_data[index3[i] + num1 + num2, 304], dtype=float)
y_test_tab = tf.convert_to_tensor(y_test_tab)
y_test = y_test_tab
# print(y_test_tab)

# %%
folder_path = r'new_images_with_folder/' + info_data[2][1]
dirs = os.listdir(folder_path)
dirpath = folder_path + '/' + dirs[0]
img = Image.open(dirpath)
# out = img.resize((290, 448), Image.LANCZOS)
img_plt = np.array(img)
x_train1 = img_plt
print(x_train1.shape)
plt.imshow(x_train1, cmap=plt.cm.binary)
plt.show()

# %% [markdown]
# **Please take note of the image dimensions. For interior images, each image has dimensions of 300x448x3, whereas for exterior images, each image has dimensions of 290x448x3.**

# %%
# assign the image data
image = np.zeros((290, 448, 3))
x_train = np.zeros((num1, 290, 448, 3))  # 2055x224x224x3
x_validation = np.zeros((num2, 290, 448, 3))  # 258x224x224x3
x_test = np.zeros((num3, 290, 448, 3))  # 258x224x224x3
# image = image_data[0]

# train data
for i in range(num1):
    folder_path = r'new_images_with_folder/' + info_data[index1[i]][1]
    dirs = os.listdir(folder_path)
    print(i)
    if len(dirs) > 0:
        # only one total picture
        dirpath = folder_path + '/' + dirs[0]  # get the angular front view of the car
        img = Image.open(dirpath)
        img_plt = np.array(img)
        x_train[i, :, :, :] = img_plt / 255.0


# validation data
for i in range(num2):
    folder_path = r'new_images_with_folder/' + info_data[index2[i]+num1][1]
    dirs = os.listdir(folder_path)
    print(i)
    if len(dirs) > 0:
        # only one total picture
        dirpath = folder_path + '/' + dirs[0]  # get the angular front view of the car
        img = Image.open(dirpath)
        img_plt = np.array(img)
        x_validation[i, :, :, :] = img_plt / 255.0


# test data
for i in range(num3):
    folder_path = r'new_images_with_folder/' + info_data[index3[i]+num1+num2][1]
    dirs = os.listdir(folder_path)
    print(i)
    if len(dirs) > 0:
        # only one total picture
        dirpath = folder_path + '/' + dirs[0]  # get the angular front view of the car
        img = Image.open(dirpath)
        img_plt = np.array(img)
        x_test[i, :, :, :] = img_plt / 255.0


x_train = tf.convert_to_tensor(x_train)
x_validation = tf.convert_to_tensor(x_validation)
x_test = tf.convert_to_tensor(x_test)
print(x_test.shape)
print(x_test[0].shape)
print(x_test.shape)

# plt.imshow(x_test[3], cmap=plt.cm.binary)
# plt.show()

print(y_train.shape)
print(y_validation.shape)
print(y_test.shape)

# %%
print(x_train.shape)
print(y_train.shape)
plt.imshow(x_train[0], cmap=plt.cm.binary)
plt.show()
# plt.imshow(x_train[2403], cmap=plt.cm.binary)
# plt.show()

print(x_validation.shape)
plt.imshow(x_validation[0], cmap=plt.cm.binary)
plt.show()
# plt.imshow(x_validation[802], cmap=plt.cm.binary)
# plt.show()

print(x_test.shape)
print(y_test.shape)
plt.imshow(x_test[0], cmap=plt.cm.binary)
plt.show()
# plt.imshow(x_test[764], cmap=plt.cm.binary)
# plt.show()
# Out:
# (2055, 290, 448, 3)
# (2055, 1)
# (258, 290, 448, 3)
# (258, 290, 448, 3)
# (258, 1)

# %% [markdown]
# ## **2 Construct CNN Model**

# %%
# 4 construct CNN model
# adam_optimizer = Adam(learning_rate=0.00023)
adam_optimizer = Adam(learning_rate=0.0001)
rms_prop_optimizer = RMSprop(learning_rate=0.001)
sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=False)

# %%
fc = 32

input_tensor = Input(shape=image.shape, name='Img_input')
base_model = VGG16(include_top=False, weights='imagenet', input_shape=image.shape, input_tensor=None)

x = base_model(input_tensor)

for layer in base_model.layers:
    layer.trainable = True

x = layers.Reshape((x.shape[1]*x.shape[2], x.shape[3]), name='Img_reshape')(x)
key = layers.Dense(fc, activation='relu', name='Img_key')(x)
# query = layers.Dense(fc, activation='relu', name='Img_query')(x)
query = key
value = layers.Dense(fc, activation='relu', name='Img_value')(x)

score = tf.matmul(query, tf.transpose(key, perm=[0, 2, 1], name='Img_k_transpose'), name='Img_q_k_matual') / np.sqrt(fc)
attn = tf.nn.softmax(score, -1, name='Img_attn_softmax')
context = tf.matmul(attn, value, name='Img_a_v_matmul')

# Flatten the output layer to 1 dimension
context = layers.Flatten(name='Img_flatten_after_self_attention')(context)

# sas = after self-attention
context = layers.Dense(1024, activation='relu', name='Img_asa_dense1')(context)
context = layers.Dropout(0.2, name='Img_asa_dropout1')(context)

context = layers.Dense(100, activation='relu', name='Img_asa_dense2')(context)


# Add a final relu layer for regression output
out1x = layers.Dense(1, name='Img_out1x')(context)

model = Model(inputs=input_tensor, outputs=out1x, name='Exterior_Image_Model')

model.compile(
    optimizer=adam_optimizer,
    loss='mse',
    metrics=[tf.keras.metrics.RootMeanSquaredError(name='rmse'), 'mse', 'mae']
)

model.summary()
# Out:
# Model: "Exterior_Image_Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Img_input (InputLayer)         [(None, 290, 448, 3  0           []
#                                 )]
#
#  vgg16 (Functional)             (None, 9, 14, 512)   14714688    ['Img_input[0][0]']
#
#  Img_reshape (Reshape)          (None, 126, 512)     0           ['vgg16[0][0]']
#
#  Img_key (Dense)                (None, 126, 100)     51300       ['Img_reshape[0][0]']
#
#  Img_query (Dense)              (None, 126, 100)     51300       ['Img_reshape[0][0]']
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 100, 126)    0           ['Img_key[0][0]']
#  Lambda)
#
#  tf.linalg.matmul_2 (TFOpLambda  (None, 126, 126)    0           ['Img_query[0][0]',
#  )                                                                'tf.compat.v1.transpose_1[0][0]'
#                                                                  ]
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 126, 126)    0           ['tf.linalg.matmul_2[0][0]']
#
#  tf.nn.softmax_1 (TFOpLambda)   (None, 126, 126)     0           ['tf.math.truediv_1[0][0]']
#
#  Img_value (Dense)              (None, 126, 100)     51300       ['Img_reshape[0][0]']
#
#  tf.linalg.matmul_3 (TFOpLambda  (None, 126, 100)    0           ['tf.nn.softmax_1[0][0]',
#  )                                                                'Img_value[0][0]']
#
#  Img_flatten_after_self_attenti  (None, 12600)       0           ['tf.linalg.matmul_3[0][0]']
#  on (Flatten)
#
#  Img_asa_dense1 (Dense)         (None, 1024)         12903424    ['Img_flatten_after_self_attentio
#                                                                  n[0][0]']
#
#  Img_asa_dropout1 (Dropout)     (None, 1024)         0           ['Img_asa_dense1[0][0]']
#
#  Img_asa_dense2 (Dense)         (None, 100)          102500      ['Img_asa_dropout1[0][0]']
#
#  Img_out1x (Dense)              (None, 1)            101         ['Img_asa_dense2[0][0]']
#
# ==================================================================================================
# Total params: 27,874,613
# Trainable params: 27,874,613
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def scheduler(epoch, lr):
    min_lr = 0.0000001
    if epoch < 5:
        return lr
    else:
        if lr < min_lr:
            lr = min_lr
            return lr
        else:
          # lr = 0.00003
          return lr * tf.math.exp(-0.01)
          # return lr

# %%
reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)
early_stop = tf.keras.callbacks.EarlyStopping(patience=20, monitor="val_loss", restore_best_weights=True, verbose=1)
# EPOCHS = 200
EPOCHS = 300
history = model.fit(x_train, y_train, epochs=EPOCHS, batch_size=32, validation_data=(x_validation, y_validation),
                    shuffle=True, verbose=2, callbacks=[early_stop, reduce_lr])
print(history)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/300
# 65/65 - 12s - loss: 0.2875 - rmse: 0.5361 - mse: 0.2875 - mae: 0.2162 - val_loss: 0.0317 - val_rmse: 0.1781 - val_mse: 0.0317 - val_mae: 0.1517 - lr: 1.0000e-04 - 12s/epoch - 181ms/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/300
# 65/65 - 10s - loss: 0.0220 - rmse: 0.1483 - mse: 0.0220 - mae: 0.1180 - val_loss: 0.0210 - val_rmse: 0.1449 - val_mse: 0.0210 - val_mae: 0.1199 - lr: 1.0000e-04 - 10s/epoch - 151ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/300
# 65/65 - 10s - loss: 0.0207 - rmse: 0.1439 - mse: 0.0207 - mae: 0.1148 - val_loss: 0.0205 - val_rmse: 0.1431 - val_mse: 0.0205 - val_mae: 0.1177 - lr: 1.0000e-04 - 10s/epoch - 151ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/300
# 65/65 - 10s - loss: 0.0183 - rmse: 0.1353 - mse: 0.0183 - mae: 0.1070 - val_loss: 0.0146 - val_rmse: 0.1206 - val_mse: 0.0146 - val_mae: 0.0942 - lr: 1.0000e-04 - 10s/epoch - 154ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/300
# 65/65 - 10s - loss: 0.0189 - rmse: 0.1375 - mse: 0.0189 - mae: 0.1087 - val_loss: 0.0143 - val_rmse: 0.1195 - val_mse: 0.0143 - val_mae: 0.0938 - lr: 1.0000e-04 - 10s/epoch - 153ms/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.900498116621748e-05.
# Epoch 6/300
# 65/65 - 10s - loss: 0.0180 - rmse: 0.1342 - mse: 0.0180 - mae: 0.1057 - val_loss: 0.0156 - val_rmse: 0.1251 - val_mse: 0.0156 - val_mae: 0.0993 - lr: 9.9005e-05 - 10s/epoch - 150ms/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.801986743696034e-05.
# Epoch 7/300
# 65/65 - 10s - loss: 0.0170 - rmse: 0.1305 - mse: 0.0170 - mae: 0.1029 - val_loss: 0.0254 - val_rmse: 0.1593 - val_mse: 0.0254 - val_mae: 0.1334 - lr: 9.8020e-05 - 10s/epoch - 151ms/step
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.704455442260951e-05.
# Epoch 8/300
# 65/65 - 10s - loss: 0.0171 - rmse: 0.1307 - mse: 0.0171 - mae: 0.1026 - val_loss: 0.0142 - val_rmse: 0.1192 - val_mse: 0.0142 - val_mae: 0.0929 - lr: 9.7045e-05 - 10s/epoch - 153ms/step
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.6078947535716e-05.
# Epoch 9/300
# 65/65 - 10s - loss: 0.0163 - rmse: 0.1278 - mse: 0.0163 - mae: 0.1008 - val_loss: 0.0137 - val_rmse: 0.1171 - val_mse: 0.0137 - val_mae: 0.0921 - lr: 9.6079e-05 - 10s/epoch - 151ms/step
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.512294491287321e-05.
# Epoch 10/300
# 65/65 - 10s - loss: 0.0158 - rmse: 0.1259 - mse: 0.0158 - mae: 0.0991 - val_loss: 0.0131 - val_rmse: 0.1145 - val_mse: 0.0131 - val_mae: 0.0899 - lr: 9.5123e-05 - 10s/epoch - 153ms/step
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.417645924258977e-05.
# Epoch 11/300
# 65/65 - 10s - loss: 0.0152 - rmse: 0.1235 - mse: 0.0152 - mae: 0.0973 - val_loss: 0.0142 - val_rmse: 0.1190 - val_mse: 0.0142 - val_mae: 0.0944 - lr: 9.4176e-05 - 10s/epoch - 150ms/step
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.323938866145909e-05.
# Epoch 12/300
# 65/65 - 10s - loss: 0.0152 - rmse: 0.1231 - mse: 0.0152 - mae: 0.0977 - val_loss: 0.0126 - val_rmse: 0.1122 - val_mse: 0.0126 - val_mae: 0.0878 - lr: 9.3239e-05 - 10s/epoch - 152ms/step
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.231163858203217e-05.
# Epoch 13/300
# 65/65 - 10s - loss: 0.0156 - rmse: 0.1251 - mse: 0.0156 - mae: 0.0992 - val_loss: 0.0134 - val_rmse: 0.1156 - val_mse: 0.0134 - val_mae: 0.0899 - lr: 9.2312e-05 - 10s/epoch - 150ms/step
#
# Epoch 14: LearningRateScheduler setting learning rate to 9.139312169281766e-05.
# Epoch 14/300
# 65/65 - 10s - loss: 0.0155 - rmse: 0.1244 - mse: 0.0155 - mae: 0.0976 - val_loss: 0.0136 - val_rmse: 0.1166 - val_mse: 0.0136 - val_mae: 0.0902 - lr: 9.1393e-05 - 10s/epoch - 150ms/step
#
# Epoch 15: LearningRateScheduler setting learning rate to 9.048374340636656e-05.
# Epoch 15/300
# 65/65 - 10s - loss: 0.0161 - rmse: 0.1269 - mse: 0.0161 - mae: 0.1002 - val_loss: 0.0139 - val_rmse: 0.1178 - val_mse: 0.0139 - val_mae: 0.0919 - lr: 9.0484e-05 - 10s/epoch - 152ms/step
#
# Epoch 16: LearningRateScheduler setting learning rate to 8.95834164111875e-05.
# Epoch 16/300
# 65/65 - 10s - loss: 0.0141 - rmse: 0.1189 - mse: 0.0141 - mae: 0.0938 - val_loss: 0.0125 - val_rmse: 0.1116 - val_mse: 0.0125 - val_mae: 0.0885 - lr: 8.9583e-05 - 10s/epoch - 151ms/step
#
# Epoch 17: LearningRateScheduler setting learning rate to 8.86920461198315e-05.
# Epoch 17/300
# 65/65 - 10s - loss: 0.0131 - rmse: 0.1144 - mse: 0.0131 - mae: 0.0905 - val_loss: 0.0124 - val_rmse: 0.1113 - val_mse: 0.0124 - val_mae: 0.0887 - lr: 8.8692e-05 - 10s/epoch - 153ms/step
#
# Epoch 18: LearningRateScheduler setting learning rate to 8.78095452208072e-05.
# Epoch 18/300
# 65/65 - 10s - loss: 0.0123 - rmse: 0.1107 - mse: 0.0123 - mae: 0.0868 - val_loss: 0.0122 - val_rmse: 0.1106 - val_mse: 0.0122 - val_mae: 0.0853 - lr: 8.7810e-05 - 10s/epoch - 151ms/step
#
# Epoch 19: LearningRateScheduler setting learning rate to 8.69358264026232e-05.
# Epoch 19/300
# 65/65 - 10s - loss: 0.0120 - rmse: 0.1096 - mse: 0.0120 - mae: 0.0860 - val_loss: 0.0108 - val_rmse: 0.1038 - val_mse: 0.0108 - val_mae: 0.0807 - lr: 8.6936e-05 - 10s/epoch - 154ms/step
#
# Epoch 20: LearningRateScheduler setting learning rate to 8.607080235378817e-05.
# Epoch 20/300
# 65/65 - 10s - loss: 0.0112 - rmse: 0.1057 - mse: 0.0112 - mae: 0.0829 - val_loss: 0.0106 - val_rmse: 0.1031 - val_mse: 0.0106 - val_mae: 0.0814 - lr: 8.6071e-05 - 10s/epoch - 151ms/step
#
# Epoch 21: LearningRateScheduler setting learning rate to 8.521438576281071e-05.
# Epoch 21/300
# 65/65 - 10s - loss: 0.0110 - rmse: 0.1051 - mse: 0.0110 - mae: 0.0827 - val_loss: 0.0123 - val_rmse: 0.1110 - val_mse: 0.0123 - val_mae: 0.0895 - lr: 8.5214e-05 - 10s/epoch - 151ms/step
#
# Epoch 22: LearningRateScheduler setting learning rate to 8.436648931819946e-05.
# Epoch 22/300
# 65/65 - 10s - loss: 0.0109 - rmse: 0.1042 - mse: 0.0109 - mae: 0.0821 - val_loss: 0.0117 - val_rmse: 0.1080 - val_mse: 0.0117 - val_mae: 0.0857 - lr: 8.4366e-05 - 10s/epoch - 151ms/step
#
# Epoch 23: LearningRateScheduler setting learning rate to 8.352702570846304e-05.
# Epoch 23/300
# 65/65 - 10s - loss: 0.0092 - rmse: 0.0961 - mse: 0.0092 - mae: 0.0755 - val_loss: 0.0097 - val_rmse: 0.0987 - val_mse: 0.0097 - val_mae: 0.0767 - lr: 8.3527e-05 - 10s/epoch - 152ms/step
#
# Epoch 24: LearningRateScheduler setting learning rate to 8.269591489806771e-05.
# Epoch 24/300
# 65/65 - 10s - loss: 0.0078 - rmse: 0.0885 - mse: 0.0078 - mae: 0.0693 - val_loss: 0.0118 - val_rmse: 0.1087 - val_mse: 0.0118 - val_mae: 0.0864 - lr: 8.2696e-05 - 10s/epoch - 151ms/step
#
# Epoch 25: LearningRateScheduler setting learning rate to 8.187307685147971e-05.
# Epoch 25/300
# 65/65 - 10s - loss: 0.0077 - rmse: 0.0879 - mse: 0.0077 - mae: 0.0686 - val_loss: 0.0089 - val_rmse: 0.0941 - val_mse: 0.0089 - val_mae: 0.0747 - lr: 8.1873e-05 - 10s/epoch - 151ms/step
#
# Epoch 26: LearningRateScheduler setting learning rate to 8.105842425720766e-05.
# Epoch 26/300
# 65/65 - 10s - loss: 0.0071 - rmse: 0.0842 - mse: 0.0071 - mae: 0.0661 - val_loss: 0.0099 - val_rmse: 0.0997 - val_mse: 0.0099 - val_mae: 0.0797 - lr: 8.1058e-05 - 10s/epoch - 151ms/step
#
# Epoch 27: LearningRateScheduler setting learning rate to 8.025187707971781e-05.
# Epoch 27/300
# 65/65 - 10s - loss: 0.0064 - rmse: 0.0803 - mse: 0.0064 - mae: 0.0628 - val_loss: 0.0088 - val_rmse: 0.0940 - val_mse: 0.0088 - val_mae: 0.0737 - lr: 8.0252e-05 - 10s/epoch - 151ms/step
#
# Epoch 28: LearningRateScheduler setting learning rate to 7.945335528347641e-05.
# Epoch 28/300
# 65/65 - 10s - loss: 0.0055 - rmse: 0.0743 - mse: 0.0055 - mae: 0.0582 - val_loss: 0.0088 - val_rmse: 0.0939 - val_mse: 0.0088 - val_mae: 0.0731 - lr: 7.9453e-05 - 10s/epoch - 151ms/step
#
# Epoch 29: LearningRateScheduler setting learning rate to 7.86627788329497e-05.
# Epoch 29/300
# 65/65 - 10s - loss: 0.0053 - rmse: 0.0731 - mse: 0.0053 - mae: 0.0574 - val_loss: 0.0089 - val_rmse: 0.0943 - val_mse: 0.0089 - val_mae: 0.0745 - lr: 7.8663e-05 - 10s/epoch - 150ms/step
#
# Epoch 30: LearningRateScheduler setting learning rate to 7.788007496856153e-05.
# Epoch 30/300
# 65/65 - 10s - loss: 0.0072 - rmse: 0.0849 - mse: 0.0072 - mae: 0.0671 - val_loss: 0.0095 - val_rmse: 0.0975 - val_mse: 0.0095 - val_mae: 0.0777 - lr: 7.7880e-05 - 10s/epoch - 152ms/step
#
# Epoch 31: LearningRateScheduler setting learning rate to 7.710515637882054e-05.
# Epoch 31/300
# 65/65 - 10s - loss: 0.0047 - rmse: 0.0684 - mse: 0.0047 - mae: 0.0532 - val_loss: 0.0081 - val_rmse: 0.0898 - val_mse: 0.0081 - val_mae: 0.0700 - lr: 7.7105e-05 - 10s/epoch - 153ms/step
#
# Epoch 32: LearningRateScheduler setting learning rate to 7.633795030415058e-05.
# Epoch 32/300
# 65/65 - 10s - loss: 0.0045 - rmse: 0.0669 - mse: 0.0045 - mae: 0.0528 - val_loss: 0.0097 - val_rmse: 0.0983 - val_mse: 0.0097 - val_mae: 0.0770 - lr: 7.6338e-05 - 10s/epoch - 150ms/step
#
# Epoch 33: LearningRateScheduler setting learning rate to 7.55783767090179e-05.
# Epoch 33/300
# 65/65 - 10s - loss: 0.0044 - rmse: 0.0665 - mse: 0.0044 - mae: 0.0525 - val_loss: 0.0084 - val_rmse: 0.0916 - val_mse: 0.0084 - val_mae: 0.0712 - lr: 7.5578e-05 - 10s/epoch - 151ms/step
#
# Epoch 34: LearningRateScheduler setting learning rate to 7.482636283384636e-05.
# Epoch 34/300
# 65/65 - 10s - loss: 0.0044 - rmse: 0.0667 - mse: 0.0044 - mae: 0.0522 - val_loss: 0.0086 - val_rmse: 0.0927 - val_mse: 0.0086 - val_mae: 0.0738 - lr: 7.4826e-05 - 10s/epoch - 151ms/step
#
# Epoch 35: LearningRateScheduler setting learning rate to 7.40818286431022e-05.
# Epoch 35/300
# 65/65 - 10s - loss: 0.0035 - rmse: 0.0592 - mse: 0.0035 - mae: 0.0460 - val_loss: 0.0086 - val_rmse: 0.0926 - val_mse: 0.0086 - val_mae: 0.0752 - lr: 7.4082e-05 - 10s/epoch - 153ms/step
#
# Epoch 36: LearningRateScheduler setting learning rate to 7.334470137720928e-05.
# Epoch 36/300
# 65/65 - 10s - loss: 0.0035 - rmse: 0.0591 - mse: 0.0035 - mae: 0.0456 - val_loss: 0.0082 - val_rmse: 0.0908 - val_mse: 0.0082 - val_mae: 0.0733 - lr: 7.3345e-05 - 10s/epoch - 151ms/step
#
# Epoch 37: LearningRateScheduler setting learning rate to 7.261490827659145e-05.
# Epoch 37/300
# 65/65 - 10s - loss: 0.0036 - rmse: 0.0599 - mse: 0.0036 - mae: 0.0464 - val_loss: 0.0080 - val_rmse: 0.0897 - val_mse: 0.0080 - val_mae: 0.0702 - lr: 7.2615e-05 - 10s/epoch - 151ms/step
#
# Epoch 38: LearningRateScheduler setting learning rate to 7.189237658167258e-05.
# Epoch 38/300
# 65/65 - 10s - loss: 0.0038 - rmse: 0.0613 - mse: 0.0038 - mae: 0.0483 - val_loss: 0.0082 - val_rmse: 0.0904 - val_mse: 0.0082 - val_mae: 0.0708 - lr: 7.1892e-05 - 10s/epoch - 151ms/step
#
# Epoch 39: LearningRateScheduler setting learning rate to 7.117703353287652e-05.
# Epoch 39/300
# 65/65 - 10s - loss: 0.0032 - rmse: 0.0563 - mse: 0.0032 - mae: 0.0440 - val_loss: 0.0095 - val_rmse: 0.0975 - val_mse: 0.0095 - val_mae: 0.0767 - lr: 7.1177e-05 - 10s/epoch - 151ms/step
#
# Epoch 40: LearningRateScheduler setting learning rate to 7.046881364658475e-05.
# Epoch 40/300
# 65/65 - 10s - loss: 0.0030 - rmse: 0.0552 - mse: 0.0030 - mae: 0.0428 - val_loss: 0.0092 - val_rmse: 0.0960 - val_mse: 0.0092 - val_mae: 0.0769 - lr: 7.0469e-05 - 10s/epoch - 151ms/step
#
# Epoch 41: LearningRateScheduler setting learning rate to 6.97676368872635e-05.
# Epoch 41/300
# 65/65 - 10s - loss: 0.0033 - rmse: 0.0570 - mse: 0.0033 - mae: 0.0442 - val_loss: 0.0082 - val_rmse: 0.0906 - val_mse: 0.0082 - val_mae: 0.0723 - lr: 6.9768e-05 - 10s/epoch - 151ms/step
#
# Epoch 42: LearningRateScheduler setting learning rate to 6.907343777129427e-05.
# Epoch 42/300
# 65/65 - 10s - loss: 0.0029 - rmse: 0.0539 - mse: 0.0029 - mae: 0.0417 - val_loss: 0.0095 - val_rmse: 0.0976 - val_mse: 0.0095 - val_mae: 0.0771 - lr: 6.9073e-05 - 10s/epoch - 150ms/step
#
# Epoch 43: LearningRateScheduler setting learning rate to 6.838614353910089e-05.
# Epoch 43/300
# 65/65 - 10s - loss: 0.0037 - rmse: 0.0607 - mse: 0.0037 - mae: 0.0479 - val_loss: 0.0082 - val_rmse: 0.0905 - val_mse: 0.0082 - val_mae: 0.0714 - lr: 6.8386e-05 - 10s/epoch - 151ms/step
#
# Epoch 44: LearningRateScheduler setting learning rate to 6.770568870706484e-05.
# Epoch 44/300
# 65/65 - 10s - loss: 0.0033 - rmse: 0.0570 - mse: 0.0033 - mae: 0.0440 - val_loss: 0.0090 - val_rmse: 0.0947 - val_mse: 0.0090 - val_mae: 0.0752 - lr: 6.7706e-05 - 10s/epoch - 151ms/step
#
# Epoch 45: LearningRateScheduler setting learning rate to 6.70320077915676e-05.
# Epoch 45/300
# 65/65 - 10s - loss: 0.0029 - rmse: 0.0538 - mse: 0.0029 - mae: 0.0413 - val_loss: 0.0092 - val_rmse: 0.0960 - val_mse: 0.0092 - val_mae: 0.0763 - lr: 6.7032e-05 - 10s/epoch - 150ms/step
#
# Epoch 46: LearningRateScheduler setting learning rate to 6.636502803303301e-05.
# Epoch 46/300
# 65/65 - 10s - loss: 0.0029 - rmse: 0.0542 - mse: 0.0029 - mae: 0.0419 - val_loss: 0.0082 - val_rmse: 0.0908 - val_mse: 0.0082 - val_mae: 0.0722 - lr: 6.6365e-05 - 10s/epoch - 151ms/step
#
# Epoch 47: LearningRateScheduler setting learning rate to 6.570468394784257e-05.
# Epoch 47/300
# 65/65 - 10s - loss: 0.0030 - rmse: 0.0545 - mse: 0.0030 - mae: 0.0418 - val_loss: 0.0094 - val_rmse: 0.0971 - val_mse: 0.0094 - val_mae: 0.0785 - lr: 6.5705e-05 - 10s/epoch - 151ms/step
#
# Epoch 48: LearningRateScheduler setting learning rate to 6.505091005237773e-05.
# Epoch 48/300
# 65/65 - 10s - loss: 0.0028 - rmse: 0.0531 - mse: 0.0028 - mae: 0.0406 - val_loss: 0.0082 - val_rmse: 0.0906 - val_mse: 0.0082 - val_mae: 0.0717 - lr: 6.5051e-05 - 10s/epoch - 150ms/step
#
# Epoch 49: LearningRateScheduler setting learning rate to 6.440364086301997e-05.
# Epoch 49/300
# 65/65 - 10s - loss: 0.0028 - rmse: 0.0530 - mse: 0.0028 - mae: 0.0409 - val_loss: 0.0098 - val_rmse: 0.0991 - val_mse: 0.0098 - val_mae: 0.0796 - lr: 6.4404e-05 - 10s/epoch - 151ms/step
#
# Epoch 50: LearningRateScheduler setting learning rate to 6.376281089615077e-05.
# Epoch 50/300
# 65/65 - 10s - loss: 0.0026 - rmse: 0.0514 - mse: 0.0026 - mae: 0.0393 - val_loss: 0.0116 - val_rmse: 0.1077 - val_mse: 0.0116 - val_mae: 0.0861 - lr: 6.3763e-05 - 10s/epoch - 151ms/step
#
# Epoch 51: LearningRateScheduler setting learning rate to 6.31283619441092e-05.
# Epoch 51/300
# 65/65 - 10s - loss: 0.0028 - rmse: 0.0526 - mse: 0.0028 - mae: 0.0405 - val_loss: 0.0082 - val_rmse: 0.0907 - val_mse: 0.0082 - val_mae: 0.0713 - lr: 6.3128e-05 - 10s/epoch - 150ms/step
#
# Epoch 52: LearningRateScheduler setting learning rate to 6.250022124731913e-05.
# Epoch 52/300
# 65/65 - 10s - loss: 0.0027 - rmse: 0.0522 - mse: 0.0027 - mae: 0.0401 - val_loss: 0.0077 - val_rmse: 0.0880 - val_mse: 0.0077 - val_mae: 0.0690 - lr: 6.2500e-05 - 10s/epoch - 152ms/step
#
# Epoch 53: LearningRateScheduler setting learning rate to 6.187833059811965e-05.
# Epoch 53/300
# 65/65 - 10s - loss: 0.0026 - rmse: 0.0512 - mse: 0.0026 - mae: 0.0399 - val_loss: 0.0104 - val_rmse: 0.1017 - val_mse: 0.0104 - val_mae: 0.0820 - lr: 6.1878e-05 - 10s/epoch - 150ms/step
#
# Epoch 54: LearningRateScheduler setting learning rate to 6.126263178884983e-05.
# Epoch 54/300
# 65/65 - 10s - loss: 0.0027 - rmse: 0.0515 - mse: 0.0027 - mae: 0.0398 - val_loss: 0.0083 - val_rmse: 0.0912 - val_mse: 0.0083 - val_mae: 0.0719 - lr: 6.1263e-05 - 10s/epoch - 150ms/step
#
# Epoch 55: LearningRateScheduler setting learning rate to 6.065305933589116e-05.
# Epoch 55/300
# 65/65 - 10s - loss: 0.0028 - rmse: 0.0529 - mse: 0.0028 - mae: 0.0411 - val_loss: 0.0089 - val_rmse: 0.0944 - val_mse: 0.0089 - val_mae: 0.0757 - lr: 6.0653e-05 - 10s/epoch - 151ms/step
#
# Epoch 56: LearningRateScheduler setting learning rate to 6.0049551393603906e-05.
# Epoch 56/300
# 65/65 - 10s - loss: 0.0026 - rmse: 0.0508 - mse: 0.0026 - mae: 0.0390 - val_loss: 0.0076 - val_rmse: 0.0874 - val_mse: 0.0076 - val_mae: 0.0689 - lr: 6.0050e-05 - 10s/epoch - 151ms/step
#
# Epoch 57: LearningRateScheduler setting learning rate to 5.945204975432716e-05.
# Epoch 57/300
# 65/65 - 10s - loss: 0.0027 - rmse: 0.0517 - mse: 0.0027 - mae: 0.0397 - val_loss: 0.0082 - val_rmse: 0.0905 - val_mse: 0.0082 - val_mae: 0.0715 - lr: 5.9452e-05 - 10s/epoch - 150ms/step
#
# Epoch 58: LearningRateScheduler setting learning rate to 5.886049257242121e-05.
# Epoch 58/300
# 65/65 - 10s - loss: 0.0025 - rmse: 0.0502 - mse: 0.0025 - mae: 0.0383 - val_loss: 0.0125 - val_rmse: 0.1116 - val_mse: 0.0125 - val_mae: 0.0913 - lr: 5.8860e-05 - 10s/epoch - 150ms/step
#
# Epoch 59: LearningRateScheduler setting learning rate to 5.827482164022513e-05.
# Epoch 59/300
# 65/65 - 10s - loss: 0.0028 - rmse: 0.0525 - mse: 0.0028 - mae: 0.0404 - val_loss: 0.0076 - val_rmse: 0.0870 - val_mse: 0.0076 - val_mae: 0.0691 - lr: 5.8275e-05 - 10s/epoch - 153ms/step
#
# Epoch 60: LearningRateScheduler setting learning rate to 5.769497875007801e-05.
# Epoch 60/300
# 65/65 - 10s - loss: 0.0026 - rmse: 0.0511 - mse: 0.0026 - mae: 0.0392 - val_loss: 0.0099 - val_rmse: 0.0995 - val_mse: 0.0099 - val_mae: 0.0786 - lr: 5.7695e-05 - 10s/epoch - 150ms/step
#
# Epoch 61: LearningRateScheduler setting learning rate to 5.7120905694318935e-05.
# Epoch 61/300
# 65/65 - 10s - loss: 0.0029 - rmse: 0.0535 - mse: 0.0029 - mae: 0.0409 - val_loss: 0.0092 - val_rmse: 0.0959 - val_mse: 0.0092 - val_mae: 0.0768 - lr: 5.7121e-05 - 10s/epoch - 152ms/step
#
# Epoch 62: LearningRateScheduler setting learning rate to 5.6552544265287e-05.
# Epoch 62/300
# 65/65 - 10s - loss: 0.0025 - rmse: 0.0500 - mse: 0.0025 - mae: 0.0380 - val_loss: 0.0081 - val_rmse: 0.0898 - val_mse: 0.0081 - val_mae: 0.0710 - lr: 5.6553e-05 - 10s/epoch - 150ms/step
#
# Epoch 63: LearningRateScheduler setting learning rate to 5.598983625532128e-05.
# Epoch 63/300
# 65/65 - 10s - loss: 0.0027 - rmse: 0.0516 - mse: 0.0027 - mae: 0.0395 - val_loss: 0.0086 - val_rmse: 0.0929 - val_mse: 0.0086 - val_mae: 0.0729 - lr: 5.5990e-05 - 10s/epoch - 151ms/step
#
# Epoch 64: LearningRateScheduler setting learning rate to 5.5432727094739676e-05.
# Epoch 64/300
# 65/65 - 10s - loss: 0.0028 - rmse: 0.0531 - mse: 0.0028 - mae: 0.0408 - val_loss: 0.0114 - val_rmse: 0.1069 - val_mse: 0.0114 - val_mae: 0.0856 - lr: 5.5433e-05 - 10s/epoch - 150ms/step
#
# Epoch 65: LearningRateScheduler setting learning rate to 5.488116221386008e-05.
# Epoch 65/300
# 65/65 - 10s - loss: 0.0026 - rmse: 0.0510 - mse: 0.0026 - mae: 0.0395 - val_loss: 0.0114 - val_rmse: 0.1068 - val_mse: 0.0114 - val_mae: 0.0857 - lr: 5.4881e-05 - 10s/epoch - 152ms/step
#
# Epoch 66: LearningRateScheduler setting learning rate to 5.4335087043000385e-05.
# Epoch 66/300
# 65/65 - 10s - loss: 0.0025 - rmse: 0.0501 - mse: 0.0025 - mae: 0.0382 - val_loss: 0.0129 - val_rmse: 0.1138 - val_mse: 0.0129 - val_mae: 0.0924 - lr: 5.4335e-05 - 10s/epoch - 151ms/step
#
# Epoch 67: LearningRateScheduler setting learning rate to 5.379444337449968e-05.
# Epoch 67/300
# 65/65 - 10s - loss: 0.0027 - rmse: 0.0517 - mse: 0.0027 - mae: 0.0392 - val_loss: 0.0087 - val_rmse: 0.0932 - val_mse: 0.0087 - val_mae: 0.0742 - lr: 5.3794e-05 - 10s/epoch - 151ms/step
#
# Epoch 68: LearningRateScheduler setting learning rate to 5.325918027665466e-05.
# Epoch 68/300
# 65/65 - 10s - loss: 0.0027 - rmse: 0.0517 - mse: 0.0027 - mae: 0.0397 - val_loss: 0.0092 - val_rmse: 0.0958 - val_mse: 0.0092 - val_mae: 0.0772 - lr: 5.3259e-05 - 10s/epoch - 151ms/step
#
# Epoch 69: LearningRateScheduler setting learning rate to 5.2729243179783225e-05.
# Epoch 69/300
# 65/65 - 10s - loss: 0.0024 - rmse: 0.0491 - mse: 0.0024 - mae: 0.0377 - val_loss: 0.0103 - val_rmse: 0.1013 - val_mse: 0.0103 - val_mae: 0.0814 - lr: 5.2729e-05 - 10s/epoch - 150ms/step
#
# Epoch 70: LearningRateScheduler setting learning rate to 5.2204577514203265e-05.
# Epoch 70/300
# 65/65 - 10s - loss: 0.0023 - rmse: 0.0484 - mse: 0.0023 - mae: 0.0365 - val_loss: 0.0086 - val_rmse: 0.0927 - val_mse: 0.0086 - val_mae: 0.0742 - lr: 5.2205e-05 - 10s/epoch - 151ms/step
#
# Epoch 71: LearningRateScheduler setting learning rate to 5.168513234821148e-05.
# Epoch 71/300
# 65/65 - 10s - loss: 0.0023 - rmse: 0.0484 - mse: 0.0023 - mae: 0.0364 - val_loss: 0.0087 - val_rmse: 0.0932 - val_mse: 0.0087 - val_mae: 0.0750 - lr: 5.1685e-05 - 10s/epoch - 150ms/step
#
# Epoch 72: LearningRateScheduler setting learning rate to 5.1170856750104576e-05.
# Epoch 72/300
# 65/65 - 10s - loss: 0.0026 - rmse: 0.0508 - mse: 0.0026 - mae: 0.0390 - val_loss: 0.0083 - val_rmse: 0.0910 - val_mse: 0.0083 - val_mae: 0.0718 - lr: 5.1171e-05 - 10s/epoch - 150ms/step
#
# Epoch 73: LearningRateScheduler setting learning rate to 5.066169978817925e-05.
# Epoch 73/300
# 65/65 - 10s - loss: 0.0024 - rmse: 0.0488 - mse: 0.0024 - mae: 0.0373 - val_loss: 0.0111 - val_rmse: 0.1053 - val_mse: 0.0111 - val_mae: 0.0832 - lr: 5.0662e-05 - 10s/epoch - 151ms/step
#
# Epoch 74: LearningRateScheduler setting learning rate to 5.015760689275339e-05.
# Epoch 74/300
# 65/65 - 10s - loss: 0.0025 - rmse: 0.0495 - mse: 0.0025 - mae: 0.0377 - val_loss: 0.0081 - val_rmse: 0.0899 - val_mse: 0.0081 - val_mae: 0.0712 - lr: 5.0158e-05 - 10s/epoch - 151ms/step
#
# Epoch 75: LearningRateScheduler setting learning rate to 4.9658530770102516e-05.
# Epoch 75/300
# 65/65 - 10s - loss: 0.0024 - rmse: 0.0485 - mse: 0.0024 - mae: 0.0368 - val_loss: 0.0091 - val_rmse: 0.0953 - val_mse: 0.0091 - val_mae: 0.0753 - lr: 4.9659e-05 - 10s/epoch - 152ms/step
#
# Epoch 76: LearningRateScheduler setting learning rate to 4.916442048852332e-05.
# Epoch 76/300
# 65/65 - 10s - loss: 0.0022 - rmse: 0.0468 - mse: 0.0022 - mae: 0.0356 - val_loss: 0.0099 - val_rmse: 0.0997 - val_mse: 0.0099 - val_mae: 0.0801 - lr: 4.9164e-05 - 10s/epoch - 151ms/step
#
# Epoch 77: LearningRateScheduler setting learning rate to 4.8675225116312504e-05.
# Epoch 77/300
# 65/65 - 10s - loss: 0.0025 - rmse: 0.0497 - mse: 0.0025 - mae: 0.0378 - val_loss: 0.0083 - val_rmse: 0.0910 - val_mse: 0.0083 - val_mae: 0.0720 - lr: 4.8675e-05 - 10s/epoch - 151ms/step
#
# Epoch 78: LearningRateScheduler setting learning rate to 4.819089735974558e-05.
# Epoch 78/300
# 65/65 - 10s - loss: 0.0023 - rmse: 0.0477 - mse: 0.0023 - mae: 0.0359 - val_loss: 0.0083 - val_rmse: 0.0911 - val_mse: 0.0083 - val_mae: 0.0719 - lr: 4.8191e-05 - 10s/epoch - 150ms/step
#
# Epoch 79: LearningRateScheduler setting learning rate to 4.771138992509805e-05.
# Epoch 79/300
# Restoring model weights from the end of the best epoch: 59.
# 65/65 - 10s - loss: 0.0024 - rmse: 0.0489 - mse: 0.0024 - mae: 0.0370 - val_loss: 0.0087 - val_rmse: 0.0935 - val_mse: 0.0087 - val_mae: 0.0745 - lr: 4.7711e-05 - 10s/epoch - 152ms/step
# Epoch 79: early stopping
# <keras.callbacks.History object at 0x7f762dcc4250>

# %% [markdown]
# ## **3 Model Evaluation and Results**

# %%
test_loss, test_rmse, test_mse, test_mae = model.evaluate(x_test, y_test, verbose=2)
validation_loss, validation_rmse, validation_mse, validation_mae = model.evaluate(x_validation, y_validation, verbose=2)
train_loss, train_rmse, train_mse, train_mae = model.evaluate(x_train, y_train, verbose=2)
# Out:
# 9/9 - 1s - loss: 0.0076 - rmse: 0.0870 - mse: 0.0076 - mae: 0.0654 - 599ms/epoch - 67ms/step
# 9/9 - 1s - loss: 0.0076 - rmse: 0.0870 - mse: 0.0076 - mae: 0.0691 - 587ms/epoch - 65ms/step
# 65/65 - 4s - loss: 0.0019 - rmse: 0.0438 - mse: 0.0019 - mae: 0.0335 - 4s/epoch - 66ms/step

# %%
result = model.predict(x_test)
# print(result)
# print(result[0])
# Out:
# 9/9 [==============================] - 1s 60ms/step

# %%
figure(figsize=(4, 3), dpi=80)
plt.scatter(y_test, result, s=3)
# plt.legend()
x = [0, 1]
y = [0, 1]
plt.plot(x, y, color="black")
plt.xlabel(var + ' ground truth')
plt.ylabel(var + ' prediction')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.tight_layout()
plt.show()

# plot_history(history)

# %%
from math import nan
test = np.array(y_test).T
# print(test)
predict = np.array(result).T

correlation_matrix = np.corrcoef(test, predict)
print(correlation_matrix)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
##range: 0.8199158648859902

print (r_squared)
# Out:
# [[1.         0.72598584]
#  [0.72598584 1.        ]]
# 0.5270554345783017

# %% [markdown]
# ## **4 Store the Model & Train, Validation and Test Results**

# %%
output = pd.DataFrame()
idx = 0
output.loc[idx, 'train_rmse'] = train_rmse
output.loc[idx, 'train_mse'] = train_mse
output.loc[idx, 'train_mae'] = train_mae

output.loc[idx, 'validation_rmse'] = validation_rmse
output.loc[idx, 'validation_mse'] = validation_mse
output.loc[idx, 'validation_mae'] = validation_mae

output.loc[idx, 'test_rmse'] = test_rmse
output.loc[idx, 'test_mse'] = test_mse
output.loc[idx, 'test_mae'] = test_mae

output.loc[idx, 'r^2'] = r_squared
pd.set_option('display.max_columns', None)
print(output)

output.to_csv('exterior_image_unimodal_value.csv')

# %%
# store the model
# summarize the loaded model
model.summary()
# save the best performing model to file
model.save('model weight/' + var + '_Ex_Img.h5')
# Out:
# Model: "Exterior_Image_Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Img_input (InputLayer)         [(None, 290, 448, 3  0           []
#                                 )]
#
#  vgg16 (Functional)             (None, 9, 14, 512)   14714688    ['Img_input[0][0]']
#
#  Img_reshape (Reshape)          (None, 126, 512)     0           ['vgg16[0][0]']
#
#  Img_key (Dense)                (None, 126, 100)     51300       ['Img_reshape[0][0]']
#
#  Img_query (Dense)              (None, 126, 100)     51300       ['Img_reshape[0][0]']
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 100, 126)    0           ['Img_key[0][0]']
#  Lambda)
#
#  tf.linalg.matmul_2 (TFOpLambda  (None, 126, 126)    0           ['Img_query[0][0]',
#  )                                                                'tf.compat.v1.transpose_1[0][0]'
#                                                                  ]
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 126, 126)    0           ['tf.linalg.matmul_2[0][0]']
#
#  tf.nn.softmax_1 (TFOpLambda)   (None, 126, 126)     0           ['tf.math.truediv_1[0][0]']
#
#  Img_value (Dense)              (None, 126, 100)     51300       ['Img_reshape[0][0]']
#
#  tf.linalg.matmul_3 (TFOpLambda  (None, 126, 100)    0           ['tf.nn.softmax_1[0][0]',
#  )                                                                'Img_value[0][0]']
#
#  Img_flatten_after_self_attenti  (None, 12600)       0           ['tf.linalg.matmul_3[0][0]']
#  on (Flatten)
#
#  Img_asa_dense1 (Dense)         (None, 1024)         12903424    ['Img_flatten_after_self_attentio
#                                                                  n[0][0]']
#
#  Img_asa_dropout1 (Dropout)     (None, 1024)         0           ['Img_asa_dense1[0][0]']
#
#  Img_asa_dense2 (Dense)         (None, 100)          102500      ['Img_asa_dropout1[0][0]']
#
#  Img_out1x (Dense)              (None, 1)            101         ['Img_asa_dense2[0][0]']
#
# ==================================================================================================
# Total params: 27,874,613
# Trainable params: 27,874,613
# Non-trainable params: 0
# __________________________________________________________________________________________________
